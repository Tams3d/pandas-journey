# %% [markdown]
# # Accessing DataFrame

# %%
import pandas as pd

# %%
movies = pd.read_csv("data/movies.csv")
ipl = pd.read_csv("data/ipl-matches.csv")

# %%
students = pd.DataFrame(
    {
        "name": ["Arun", "Maya", "Ram", "Priya"],
        "iq": [100, 90, 80, 120],
        "marks": [80, 70, 60, 90],
        "package": [10, 6, 5, 15],
    }
).set_index("name")
students
# Out:
#         iq  marks  package
# name
# Arun   100     80       10
# Maya    90     70        6
# Ram     80     60        5
# Priya  120     90       15

# %% [markdown]
# ## Columns

# %% [markdown]
# ### Using Column Name

# %%
movies["title_x"]
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
movies[["year_of_release", "title_x", "actors"]]
# Out:
#       year_of_release                               title_x  \
# 0                2019              Uri: The Surgical Strike
# 1                2019                         Battalion 609
# 2                2019  The Accidental Prime Minister (film)
# 3                2019                       Why Cheat India
# 4                2018                       Evening Shadows
# ...               ...                                   ...
# 1624             2001                 Tera Mera Saath Rahen
# 1625             2001                  Yeh Zindagi Ka Safar
# 1626             2018                       Sabse Bada Sukh
# 1627             2019                                 Daaka
# 1628             2011                              Humsafar
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %% [markdown]
# ## Rows

# %% [markdown]
# ### Using Index Positions

# %%
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %% [markdown]
# #### Fancy Indexing

# %%
movies.iloc[[0, 7, 10]]
# Out:
#                      title_x    imdb_id  \
# 0   Uri: The Surgical Strike  tt8291224
# 7                 Bombairiya  tt4971258
# 10                    Amavas  tt8396186
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 7            https://en.wikipedia.org/wiki/Bombairiya
# 10               https://en.wikipedia.org/wiki/Amavas
#
#                      title_y            original_title  is_adult  \
# 0   Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 7                 Bombairiya                Bombairiya         0
# 10                    Amavas                    Amavas         0
#
#     year_of_release runtime              genres  imdb_rating  imdb_votes  \
# ...

# %% [markdown]
# ### Using Index Name
#
# - Both start and end are included

# %%
students.loc["Arun":"Maya"]
# Out:
#        iq  marks  package
# name
# Arun  100     80       10
# Maya   90     70        6

# %% [markdown]
# #### Fancy Indexing

# %%
students.loc[["Maya", "Arun"]]
# Out:
#        iq  marks  package
# name
# Maya   90     70        6
# Arun  100     80       10

# %% [markdown]
# ## Both Rows and Columns

# %%
movies.iloc[0:3, 0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
# students["iq"].loc["Arun"] is equivalent but not recommended
students.loc["Arun", "iq"]
# Out:
# np.int64(100)
